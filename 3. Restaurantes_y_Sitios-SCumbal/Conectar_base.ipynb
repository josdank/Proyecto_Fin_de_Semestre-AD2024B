# %%
import sqlite3
import pandas as pd
from sqlalchemy import create_engine
from faker import Faker
from pymongo import MongoClient

# %%
Restaurantes = pd.read_csv("Restaurantes_base.csv")
# Out:
# C:\Users\santp\AppData\Local\Temp\ipykernel_16244\3666696505.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   Restaurantes = pd.read_csv("Restaurantes_base.csv")

# %%
Restaurantes
# Out:
#                                                      name  \
# 0                                Abby Rappoport, LAC, CMQ
# 1                                           The UPS Store
# 2                                                  Target
# 3                                      St Honore Pastries
# 4                                Perkiomen Valley Brewery
# ...                                                   ...
# 202058  Best Brews - Four Points by Sheraton Bengaluru...
# 202059                           Vinod Bar And Restaurant
# 202060  Plunge - Sheraton Grand Bengaluru Whitefield H...
# 202061  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 202062                       The Nest - The Den Bengaluru
#
#                                                   address           city  \
# 0                                  1616 Chapala St, Ste 2  Santa Barbara
# 1                         87 Grasso Plaza Shopping Center         Affton
# ...

# %%
USER = 'root'
PASSWORD = '12345'
HOST = 'localhost:3306'
DATABASE = 'Negocios'
engine = create_engine(f'mysql+mysqlconnector://{USER}:{PASSWORD}@{HOST}/{DATABASE}')

# %%
Restaurantes.to_sql('restaurantes', con=engine, if_exists='replace', index=True)
# Out:
# 202063

# %%
cliente = MongoClient("mongodb://localhost:27017/")
db = cliente["Negocios"]
coleccion = db["Restaurantes"]

# %%
datos = pd.read_csv("Restaurantes_base.csv").to_dict(orient="records")
coleccion.insert_many(datos)
