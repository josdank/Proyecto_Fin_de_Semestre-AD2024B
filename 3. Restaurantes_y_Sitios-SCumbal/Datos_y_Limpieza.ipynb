# %%
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd

# %%
yelp = pd.read_json("yelp_academic_dataset_business.json", lines=True)

yelp
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
dfyelp = yelp.drop(['attributes', 'hours'], axis=1)
dfyelp.to_csv('yelp.csv', index=False)

# %%
zomato = pd.read_csv("zomato.csv")
zomato
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
columnas_eliminar = [
    'online_order', 'book_table', 'phone', 'location', 
    'rest_type', 'dish_liked', 'cuisines', 
    'approx_cost(for two people)', 'menu_item', 'reviews_list'
]

columnas_presentes = [col for col in columnas_eliminar if col in df.columns]
zomato.drop(columns=columnas_presentes, inplace=True)

# Renombrar columnas para mayor consistencia
zomato.rename(columns={
    'url': 'business_id',
    'rate': 'stars',
    'votes': 'review_count',
    'listed_in(city)': 'city',
    'address': 'address',
    'name': 'name',
    'listed_in(type)': 'categories',
}, inplace=True)
zomato.to_csv('zomato1.csv', index=False)
zomato
# Out:
#                                              business_id  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %%
dfyelp
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1       mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2       tUFrWirKiKi_TAnsVWINQQ                    Target
# 3       MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4       mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
# ...                        ...                       ...
# 150341  IUQopTMmYQG-qRtBk-8QnA              Binh's Nails
# 150342  c8GjPIOTGVmIemT7j5_SyQ      Wild Birds Unlimited
# 150343  _QAMST-NrQobXduilWEqSw         Claire's Boutique
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                                 address           city state postal_code  \
# 0                1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1       87 Grasso Plaza Shopping Center         Affton    MO       63123
# ...

# %%
d1=pd.read_csv("yelp.csv")
d2=pd.read_csv("zomato1.csv")
dfn=pd.concat([d1,d2])
dfn
# Out:
#                                              business_id  \
# 0                                 Pns2l4eNsfO8kk83dixA6A
# 1                                 mpf3x-BjTdTEA3yCZrAYPw
# 2                                 tUFrWirKiKi_TAnsVWINQQ
# 3                                 MTSW4McQd7CbVtyjqoe9mw
# 4                                 mWMc6_wTdE0EUBKIGXDVfA
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                     name  \
# 0                               Abby Rappoport, LAC, CMQ
# 1                                          The UPS Store
# 2                                                 Target
# ...

# %%
null_columns = df.isnull().sum()
null_columns
# Out:
# business_id       0
# name              0
# address           0
# city              0
# state             0
# postal_code       0
# latitude          0
# longitude         0
# stars             0
# review_count      0
# is_open           0
# categories      103
# dtype: int64

# %%
dfn.drop(columns='business_id', inplace=True)

# %%
dfn
# Out:
#                                                     name  \
# 0                               Abby Rappoport, LAC, CMQ
# 1                                          The UPS Store
# 2                                                 Target
# 3                                     St Honore Pastries
# 4                               Perkiomen Valley Brewery
# ...                                                  ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...
# 51713                           Vinod Bar And Restaurant
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                       The Nest - The Den Bengaluru
#
#                                                  address           city state  \
# 0                                 1616 Chapala St, Ste 2  Santa Barbara    CA
# 1                        87 Grasso Plaza Shopping Center         Affton    MO
# ...

# %%
dfn['stars'] = df['stars'].astype(str).str.replace(r'/5', '', regex=True)
dfn['stars'] = df['stars'].replace('nan', 2.5).astype(float)
dfn['is_open'] = df['is_open'].replace('nan', 0.0).astype(float)
dfn
# Out:
#                                                     name  \
# 0                               Abby Rappoport, LAC, CMQ
# 1                                          The UPS Store
# 2                                                 Target
# 3                                     St Honore Pastries
# 4                               Perkiomen Valley Brewery
# ...                                                  ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...
# 51713                           Vinod Bar And Restaurant
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                       The Nest - The Den Bengaluru
#
#                                                  address           city state  \
# 0                                 1616 Chapala St, Ste 2  Santa Barbara    CA
# 1                        87 Grasso Plaza Shopping Center         Affton    MO
# ...

# %%
dfn.fillna({
    'state': 'DES',
    'postal_code': 10000,
    'latitude': 1.0,
    'longitude': 1.0
}, inplace=True)

dfn
# Out:
#                                                     name  \
# 0                               Abby Rappoport, LAC, CMQ
# 1                                          The UPS Store
# 2                                                 Target
# 3                                     St Honore Pastries
# 4                               Perkiomen Valley Brewery
# ...                                                  ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...
# 51713                           Vinod Bar And Restaurant
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...
# 51716                       The Nest - The Den Bengaluru
#
#                                                  address           city state  \
# 0                                 1616 Chapala St, Ste 2  Santa Barbara    CA
# 1                        87 Grasso Plaza Shopping Center         Affton    MO
# ...

# %%
dfn.to_csv('Restaurantes_base.csv', index=False)
